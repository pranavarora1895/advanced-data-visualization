# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
diamonds_df = pd.read_csv('diamonds.csv')
diamonds_df
# Out:
#               id                                                url    shape  \
# 0       10086429  https://www.brilliantearth.com//loose-diamonds...    Round
# 1       10016334  https://www.brilliantearth.com//loose-diamonds...  Emerald
# 2        9947216  https://www.brilliantearth.com//loose-diamonds...  Emerald
# 3       10083437  https://www.brilliantearth.com//loose-diamonds...    Round
# 4        9946136  https://www.brilliantearth.com//loose-diamonds...  Emerald
# ...          ...                                                ...      ...
# 119100  10081678  https://www.brilliantearth.com//lab-diamonds-s...    Round
# 119101   9521564  https://www.brilliantearth.com//lab-diamonds-s...  Cushion
# 119102   9896730  https://www.brilliantearth.com//lab-diamonds-s...  Cushion
# 119103   9756570  https://www.brilliantearth.com//lab-diamonds-s...     Oval
# 119104   9293400  https://www.brilliantearth.com//lab-diamonds-s...  Cushion
#
#          price  carat          cut colour clarity report     type  \
# 0          400   0.30    Very Good      J     SI2    GIA  natural
# 1          400   0.31        Ideal      I     SI1    GIA  natural
# 2          400   0.30        Ideal      I     VS2    GIA  natural
# 3          400   0.30        Ideal      I     SI2    GIA  natural
# 4          400   0.30        Ideal      I     SI1    GIA  natural
# ...        ...    ...          ...    ...     ...    ...      ...
# 119100   99040   5.71  Super Ideal      D    VVS2   GCAL      lab
# 119101  107330  15.32    Very Good      G     SI2    IGI      lab
# 119102  110110  10.05        Ideal      D     SI2    IGI      lab
# 119103  126030  10.33         Fair      D     VS2    IGI      lab
# 119104  141710  10.25         Good      E     VS1    IGI      lab
#
#                date_fetched
# 0       2020-11-29 12-26 PM
# 1       2020-11-29 12-26 PM
# 2       2020-11-29 12-26 PM
# 3       2020-11-29 12-26 PM
# 4       2020-11-29 12-26 PM
# ...                     ...
# 119100  2020-11-29 12-26 PM
# 119101  2020-11-29 12-26 PM
# 119102  2020-11-29 12-26 PM
# 119103  2020-11-29 12-26 PM
# 119104  2020-11-29 12-26 PM
#
# [119105 rows x 11 columns]

# %% [markdown]
# ## Answer 1
#
# - Use `@interact` to toggle options
# - Checking the origin of the data
# - Pivoting the data to feed into the heatmap
# - Plotting the heatmap

# %%
@interact(Origin=(['All','Natural','Lab']))
def plot_diamond(Origin):

    clarity_order = ['SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']

    if Origin=='Natural':
        data = diamonds_df[diamonds_df['type'] == 'natural']
    elif Origin=='Lab':
        data = diamonds_df[diamonds_df['type'] == 'lab']
    else:
        data = diamonds_df

    heatmap_data = data.pivot_table(index='colour', columns='clarity', values='carat', aggfunc='mean')
    heatmap_data = heatmap_data[clarity_order]

    fig, ax = plt.subplots(figsize=(6, 4))
    sns.heatmap(heatmap_data, cmap='mako')
    ax.set_xlabel('clarity')
    ax.set_ylabel('color')
    plt.show()
# Out:
# interactive(children=(Dropdown(description='Origin', options=('All', 'Natural', 'Lab'), value='All'), Output()…

# %% [markdown]
# ## Attributions
#
# 1. Ipywidgets - https://pypi.org/project/ipywidgets/
# 2. Professor's Lectures - Lecture 23 and 24
